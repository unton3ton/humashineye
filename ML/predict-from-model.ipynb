# %%
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
# load weights into new model
new_model = keras.models.load_model("multi_CNN.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
new_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#Validate on an image
from keras.preprocessing import image
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# predict for my data
new_path = './test_for_model/focal_mirror.jpg'
image_result=Image.open(new_path)

img_width,img_height = 100, 100 # как при тренировке исходной модели

def data_resizing_process(dirs):
    datas = image.load_img(dirs, target_size = (img_width,img_height))
    res = image.img_to_array(datas)
    res = np.expand_dims(res, axis = 0)
    res /= 255
    return res

# img = image.load_img(new_path, target_size=(img_width,img_height,3))
# img = image.img_to_array(img)
# img = np.expand_dims(img, axis=0)
# img = img/255.

img = data_resizing_process(new_path)
result = new_model.predict(img)
print(np.argmax(result))

Categories=disease_name
image_result=plt.imshow(image_result)
plt.title(Categories[np.argmax(result)])
plt.show()
# Out:
# 1

# %%
# predict for my data
new_path = './test_for_model/minimal_change.jpg'
image_result=Image.open(new_path)


def data_resizing_process(dirs):
    datas = image.load_img(dirs, target_size = (img_width, img_height))
    res = image.img_to_array(datas)
    res = np.expand_dims(res, axis = 0)
    res /= 255
    return res

# img = image.load_img(new_path, target_size=(img_width,img_height,3))
# img = image.img_to_array(img)
# img = np.expand_dims(img, axis=0)
# img = img/255.

img = data_resizing_process(new_path)
result = new_model.predict(img)
print(np.argmax(result))

Categories=disease_name
image_result=plt.imshow(image_result)
plt.title(Categories[np.argmax(result)])
plt.show()
# Out:
# 1

# %%
def data_resizing_process(dirs):
    datas = image.load_img(dirs, target_size = (img_width, img_height))
    res = image.img_to_array(datas)
    res = np.expand_dims(res, axis = 0)
    res /= 255
    return res

for i in range(1,10): 
    new_path = f'./retinal-disease-classification/Test_Set/Test_Set/Test/{i}.png'
    image_result=Image.open(new_path)
    
    img = data_resizing_process(new_path)
    result = new_model.predict(img)

    Categories=disease_name
    image_result=plt.imshow(image_result)
    plt.title(Categories[np.argmax(result)])
    plt.show()
